# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here

import requests

import json

import pandas as pd
pd.set_option('display.max_columns', None) #shows all the columns of the table

#pd.set_option('display.max_rows', None) #shows all the rows of the table

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here

username = 'katherineling'

token = '4c2115c04cc3c67bcafcdce60ea745f2138f7c63'

gh_session = requests.Session() #you have to create a session bc you need to use a username and pw. If you did not need a username and pw, then you could just access via the "get" command with the URL
gh_session.auth = (username, token)
url = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'
forks = json.loads(gh_session.get(url).text) #info that I have as text will be converted to a json file 
forks
# Out:
# [{'id': 220066216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=',
#   'name': 'mad-oct-2018',
#   'full_name': 'ToniPons97/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'ToniPons97',
#    'id': 45130294,
#    'node_id': 'MDQ6VXNlcjQ1MTMwMjk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/45130294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ToniPons97',
#    'html_url': 'https://github.com/ToniPons97',
#    'followers_url': 'https://api.github.com/users/ToniPons97/followers',
#    'following_url': 'https://api.github.com/users/ToniPons97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ToniPons97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ToniPons97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ToniPons97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ToniPons97/orgs',
# ...

# %%
len(forks) #each fork is a dictionary, so len(forks) will be the number of dictionaries
# Out:
# 16

# %% [raw]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here

import pandas as pd

pd.set_option('display.max_columns', None)


# data = pd.DataFrame(forks)
# data.head()

# from pandas.io.json import json_normalize

# flattened_data = json_normalize(forks)

# flattened_data = pd.DataFrame(flattened_data)
# flattened_data.head()

# list_of_language_attributes = []


# array_languages = flattened_data['language'].unique()

###############

langs = []
for fork in forks:
    langs.append(fork['language'])

print(langs) #this will give you the language for each fork, so 16 languages total
print(set(langs)) #this will give you the unique languages

##############

#you can also do the loop above using list comprehension
    
# langs = [fork['language']]
# Out:
# [None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'HTML', 'Jupyter Notebook', 'Jupyter Notebook', 'Python', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']
# {'Python', 'HTML', 'Jupyter Notebook', None}

# %%
data['language']

len(data['language'])
# Out:
# 16

# %%
forks
# Out:
# [{'id': 220066216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=',
#   'name': 'mad-oct-2018',
#   'full_name': 'ToniPons97/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'ToniPons97',
#    'id': 45130294,
#    'node_id': 'MDQ6VXNlcjQ1MTMwMjk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/45130294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ToniPons97',
#    'html_url': 'https://github.com/ToniPons97',
#    'followers_url': 'https://api.github.com/users/ToniPons97/followers',
#    'following_url': 'https://api.github.com/users/ToniPons97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ToniPons97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ToniPons97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ToniPons97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ToniPons97/orgs',
# ...

# %%
len(forks)
# Out:
# 16

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

## (kat) flattened_data


##(kat) October_commits = flattened_data[flattened_data['created_at'].str.contains('2018-10')]

##(kat) print(October_commits)

## (kat) October_arrays = October_commits.values


## (kat) print(October_arrays)


############

##every dictionary is a user who has forked 

##Get commits made this year, since no commits have been made in the last week 

#formula:

# d = '2019-01-01'
# total_commits = 0

# for fork in forks:
#     commit_url = (fork['commits_url'].replace("{/sha}", "") + '?since=' + d) #this part is replacing the 'sha' with "since+date" to find all the commits made since that date
#     commits = json.loads(gh_session.get(commit_url).text)          #this will give you all the commits for one particular user. The commit URL will be the user's commit URL, without the "sha" at the end. The "sha" will be replaced with ?since=date to figure out all the commits done after that date for that particular user
#     for commit in commits:                                        
#         total_commits += 1

# print(total_commits)
        
#the question asks for all commits during month of October 2018, so you would need to find the commits "?since" Oct 2018 and "?since" Nov 2018 and subtract the two

d1 = '2018-10-01' #since
d2 = '2018-11-01' #since

total_commits1 = 0
total_commits2 = 0



for fork in forks: # list of dicts of every user that has repo-ed
    commit_url1 = (fork['commits_url'].replace("{/sha}", "") + '?since=' + d1) # '?until' is also a query operator
    commit_url2 = (fork['commits_url'].replace("{/sha}", "") + '?since=' + d2)
    commits1 = json.loads(gh_session.get(commit_url1).text)
    commits2 = json.loads(gh_session.get(commit_url2).text)
    for commit in commits1:
        total_commits1 += 1 # its checking one by one if commits in repo since after d date and summing
    for commit in commits2:
        total_commits2 += 1
            
print(total_commits1 - total_commits2)
        
##every dictionary is a user who has forked
# Out:
# 79

# %%
x = json.loads(gh_session.get('https://api.github.com/repos/rsennes/mad-oct-2018/commits?since=2019-01-01').text)
len(x)
# Out:
# 30

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
# Out:
# 10

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here


repo_url = 'https://api.github.com/repos/ironhack-datalabs/scavenger'
tree_sha = '9308ccc8a4c34c5e3a991ee815222a9691c32476'
condition = '?recursive=1'

url = repo_url + '/git/trees/' + tree_sha + condition
trees = json.loads(gh_session.get(url).text)

data = pd.DataFrame(trees)

print(data)

from pandas.io.json import json_normalize

flattened_data_tree = json_normalize(data['tree'])

print(flattened_data_tree['path'])

scavenger_files = []
for file in flattened_data_tree['path']:
    if '.scavengerhunt' in file:
        scavenger_files.append(file)
        
print(scavenger_files)

# # in the loop above, you are going through each file one by one and seeing if it has "scavengerhunt" in the name. 
# #if it does, then we would append each file to the "scavenger_files" list

################


# #  Note that these files are not arranged in an order. First we need to arrange the files

# #  from .0001 to later files and then extract the information in the files

# # we need to sort the files
# Out:
#                                           sha  \
# 0    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4    9308ccc8a4c34c5e3a991ee815222a9691c32476
# ..                                        ...
# 104  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 105  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 106  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 107  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 108  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                    url  \
# 0    https://api.github.com/repos/ironhack-datalabs...
# 1    https://api.github.com/repos/ironhack-datalabs...
# 2    https://api.github.com/repos/ironhack-datalabs...
# 3    https://api.github.com/repos/ironhack-datalabs...
# 4    https://api.github.com/repos/ironhack-datalabs...
# ..                                                 ...
# ...

# %%
# Out:
# []

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
import re
order = []

pattern = '\.\d+'
for file in scavenger_files:
    order.append(re.findall(pattern, file)[0])
files_df = pd.DataFrame(scavenger_files, columns=['FilePath'])
files_df['OrderNumbers'] = order
files_df = files_df.sort_values('OrderNumbers', ascending=True)

print(files_df.head())

# #this should give you two columns,  one with the file path and the other with the order numbers in ascending order ('.0001','.0002','.0003', etc.)
# Out:
#                      FilePath OrderNumbers
# 23  98750/.0001.scavengerhunt        .0001
# 19  88596/.0002.scavengerhunt        .0002
# 15  60224/.0003.scavengerhunt        .0003
# 16  68848/.0004.scavengerhunt        .0004
# 6   44639/.0005.scavengerhunt        .0005

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here


content = []
import base64
for file in files_df['FilePath']:
   url = repo_url+'/contents/'+file
   message = json.loads(gh_session.get(url).text)
   message = base64.b64decode(message['content']).decode("utf-8").rstrip()
   content.append(message)
print(content)
# Out:
# ['In', 'data', 'science,', '80', 'percent', 'of', 'time', 'spent', 'is', 'preparing', 'data,', '20', 'percent', 'of', 'time', 'is', 'spent', 'complaining', 'about', 'the', 'need', 'to', 'prepare', 'data.']

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

print(" ".join(content))
# Out:
# In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
