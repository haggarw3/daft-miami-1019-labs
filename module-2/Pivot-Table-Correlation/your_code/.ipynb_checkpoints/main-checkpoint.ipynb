# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd

# %% [markdown]
# # Challenge 1
#
# #### Read the `employees` dataset from Ironhack's database:
# * db: `employees`
# * table: `employees`
#
# Save your data in a variable called `employees`.

# %%
employees = pd.read_csv('C://Users/aleja/daft-miami-1019-labs/module-2/Pivot-Table-Correlation/Employee.csv')
employees
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean `Salary` by `Department`?
# **Tip**: There are 2 ways to do it: with or without pivot tables. Do it both ways.

# %%
# Method 1
employees.groupby('Department').agg({'Salary': 'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# Method 2
employees.pivot_table(index=['Department'], values='Salary')
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### Now, group the data by more than one column. Use Pandas pivot table function to select the mean `Salary` by `Department` and `Title`.

# %%
employees.pivot_table(index=['Department', 'Title'], values = 'Salary')
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### Display the number of `Years` of work experience and the `Salary` for each `Title`. Add `Years` as a column in your pivot table.
# **Hint**: Use Pandas documentation to explore the [pivot table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) function.

# %%
employees.pivot_table(index=['Title'], columns='Years', values='Salary')
# Out:
# Years         1     2     3     4     7     8
# Title
# VP          NaN   NaN   NaN   NaN   NaN  70.0
# analyst    35.0  30.0   NaN  35.0   NaN   NaN
# associate   NaN  55.0  55.0   NaN  60.0   NaN

# %% [markdown]
# #### Find the mean `Salary` and number of employees in each `Department` and for each job `Title`.

# %%
x = employees.pivot_table(index=['Department', 'Title'], values=['Name'], aggfunc='count')
y = employees.pivot_table(index=['Department', 'Title'], values=['Salary'])
pd.concat([x,y], axis =1)
# Out:
#                       Name  Salary
# Department Title
# HR         VP            1    70.0
#            analyst       2    32.5
# IT         VP            1    70.0
#            analyst       2    32.5
#            associate     1    60.0
# Sales      associate     2    55.0

# %%
employees.groupby(['Department', 'Title']).agg({'Salary': 'mean', 'Name': 'count'})
# Out:
#                       Salary  Name
# Department Title
# HR         VP           70.0     1
#            analyst      32.5     2
# IT         VP           70.0     1
#            analyst      32.5     2
#            associate    60.0     1
# Sales      associate    55.0     2

# %% [markdown]
# #### For each `Department` and each job `Title`, find the `Salary` median, minimum, maximum and standard deviation. Comment your results.

# %%
employees.groupby(['Department', 'Title']).agg({'Salary': 'max'},{'Salary': 'mean'}, {'Salary': 'min'})
# Out:
#                       Salary
# Department Title
# HR         VP             70
#            analyst        35
# IT         VP             70
#            analyst        35
#            associate      60
# Sales      associate      55

# %%
employees_data = employees.groupby(['Department', 'Title'])['Salary'].describe()[['50%', 'min', 'max', 'std']]
employees_data
# Out:
#                        50%   min   max       std
# Department Title
# HR         VP         70.0  70.0  70.0       NaN
#            analyst    32.5  30.0  35.0  3.535534
# IT         VP         70.0  70.0  70.0       NaN
#            analyst    32.5  30.0  35.0  3.535534
#            associate  60.0  60.0  60.0       NaN
# Sales      associate  55.0  55.0  55.0  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
employees.groupby(['Department', 'Title'])['Salary'].describe()[['50%', 'min', 'max', 'std', 'mean']]
# Out:
#                        50%   min   max       std  mean
# Department Title
# HR         VP         70.0  70.0  70.0       NaN  70.0
#            analyst    32.5  30.0  35.0  3.535534  32.5
# IT         VP         70.0  70.0  70.0       NaN  70.0
#            analyst    32.5  30.0  35.0  3.535534  32.5
#            associate  60.0  60.0  60.0       NaN  60.0
# Sales      associate  55.0  55.0  55.0  0.000000  55.0

# %%
employees_data.pivot_table(index=['Department', 'Title'], fill_value=0)
# Out:
#                        50%  max  min       std
# Department Title
# HR         VP         70.0   70   70  0.000000
#            analyst    32.5   35   30  3.535534
# IT         VP         70.0   70   70  0.000000
#            analyst    32.5   35   30  3.535534
#            associate  60.0   60   60  0.000000
# Sales      associate  55.0   55   55  0.000000

# %% [markdown]
# #### The stake holders want to know, for each `Department`, the number of employees and how much money is spent on salaries. Could you provide that information?

# %%
employees.groupby('Department').agg({'Name': 'count', 'Salary': 'sum'})
# Out:
#             Name  Salary
# Department
# HR             3     135
# IT             4     195
# Sales          2     110

# %%
sal = employees.pivot_table(index='Department', values='Salary', aggfunc='sum')
n_emp = employees.pivot_table(index='Department', values='Name', aggfunc='count')
pd.concat([sal, n_emp], axis=1)
# Out:
#             Salary  Name
# Department
# HR             135     3
# IT             195     4
# Sales          110     2

# %% [markdown]
# #### For each `Department` and `Title`, find the the total years of work experience and the mean `Salary`.

# %%
employees.groupby(['Department', 'Title']).agg({'Years': 'sum', 'Salary': 'mean'})
# Out:
#                       Years  Salary
# Department Title
# HR         VP             8    70.0
#            analyst        6    32.5
# IT         VP             8    70.0
#            analyst        3    32.5
#            associate      7    60.0
# Sales      associate      5    55.0

# %% [markdown]
# ## Bonus Challenge 1
#
# #### Compute the mean `Salary` after removing the maximum `Salary` for each `Department`. Create the appropriate pivot table.
# **Hint**: Write a custom function.

# %%
from statistics import mean
def maxremov_and_mean(x):
    x = list(x)
    x.sort(reverse=True)
    x = x[1:]
    return mean(x)
maxremov_and_mean(employees['Salary'])
# Out:
# 46.25

# %%
employees.groupby('Department').agg({'Salary': maxremov_and_mean})
# Out:
#                Salary
# Department
# HR          32.500000
# IT          41.666667
# Sales       55.000000

# %% [markdown]
# # Challenge 2
#
# #### Read the `fitbit` dataset from Ironhack's database:
# * db: `fitbit`
# * table: `fitbit`
#
# Save your data in a variable called `fitbit`.

# %%
fitbit = pd.read_csv('C://Users/aleja/daft-miami-1019-labs/module-2/Pivot-Table-Correlation/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# **Hint**: Use Pandas functions from previous lectures.

# %%
fitbit.dtypes
# Out:
# Date                           object
# Calorie burned                  int64
# Steps                           int64
# Distance                      float64
# Floors                          int64
# Minutes Sedentary             float64
# Minutes Lightly Active          int64
# Minutes Fairly Active           int64
# Minutes Very Active             int64
# Activity Calories               int64
# MinutesOfSleep                  int64
# MinutesOfBeingAwake             int64
# NumberOfAwakings                int64
# LengthOfRestInMinutes           int64
# Distance_miles                float64
# Days                           object
# Days_encoded                  float64
# Work_or_Weekend                 int64
# Hours Sleep                   float64
# Sleep efficiency              float64
# Yesterday_sleep               float64
# Yesterday_sleep_efficiency    float64
# Months                         object
# Months_encoded                  int64
# dtype: object

# %%
fitbit.describe()
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %% [raw]
# #### You suspect that there must be a linear relationship between the `Minutes Very Active` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit['Minutes Very Active'].corr(fitbit['Steps'])
# Out:
# 0.5714518481062605

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Very active` vs `Steps`. We'll work with matplotlib next week. As a first introduction, uncomment and complete the following code. You need to replace the # symbol for the correct function arguments.

# %%
import matplotlib.pyplot as plt

# %%
x = fitbit['Minutes Very Active']
y = fitbit['Steps']
plt.scatter(x, y)
plt.title('Plot')
plt.xlabel('Minutes Very Active')
plt.ylabel('Steps')
plt.show()

# %% [markdown]
# #### What can you say about `Minutes Very Active` and `Steps`? Write a comment below.

# %%
"""
They have a good correlation, not the best one, but even so they might have a linear relation.
"""

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `Minutes Sedentary` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit['Minutes Sedentary'].corr(fitbit['Steps'])
# Out:
# 0.07690608062990092

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Sedentary` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(fitbit['Minutes Sedentary'], fitbit['Steps'])
plt.title('Plot 2')
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.show()

# %%
"""
They have a very weak correlation and the plot shows disparity.
So they should not have a linear relationship.
"""

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `MinutesOfSleep` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit['MinutesOfSleep'].corr(fitbit['Steps'])
# Out:
# 0.13098565950836388

# %% [markdown]
# #### Use matplotlib to visually plot `MinutesOfSleep` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(fitbit['MinutesOfSleep'], fitbit['Steps'])
plt.title('MinutesOfSleep vs Steps')
plt.xlabel('MinutesOfSleep')
plt.ylabel('Steps')
plt.show()

# %%
"""
your commments here
"""

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`.

# %%
columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']

# %%
cor_fit = fitbit[['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']].corr()
cor_fit
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix, which of the features are highly correlated with variable `Steps`?
# **Hint**: sort the correlations of `Steps` vs the rest of the features in descending order. You can use Pandas `sort_values`.

# %%
cor_fit.sort_values('Steps', ascending=False)
# Out:
#                         Steps  Minutes Very Active    Floors  Calorie burned  \
# Steps                1.000000             0.571452  0.306511        0.255305
# Minutes Very Active  0.571452             1.000000  0.399503        0.197881
# Floors               0.306511             0.399503  1.000000        0.130757
# Calorie burned       0.255305             0.197881  0.130757        1.000000
# MinutesOfSleep       0.130986             0.108018  0.069464        0.011485
# Minutes Sedentary    0.076906             0.105963  0.057812        0.125353
#
#                      MinutesOfSleep  Minutes Sedentary
# Steps                      0.130986           0.076906
# Minutes Very Active        0.108018           0.105963
# Floors                     0.069464           0.057812
# Calorie burned             0.011485           0.125353
# MinutesOfSleep             1.000000           0.204242
# Minutes Sedentary          0.204242           1.000000

# %% [markdown]
# # Challenge 3
#
# #### Read the `time_grades` dataset from Ironhack's database:
# * db: `time_grades`
# * table: `time_grades`
#
# Save your data in a variable called `time_grades`.

# %%
time_grades = pd.read_excel('C://Users/aleja/daft-miami-1019-labs/module-2/Pivot-Table-Correlation/timeGrades.xlsx')
time_grades
# Out:
#         Name  Study time  Grade
# 0       Jose           4      4
# 1      Maria           9      7
# 2      David           8      9
# 3      Sonia          10      7
# 4     Samuel          20      9
# 5        Eva           5      3
# 6     Carlos          12      7
# 7      Pedro           6      5
# 8        Ana          18      9
# 9   Gervasio           7      3
# 10     Gemma           7      8
# 11    Alicia          11      7
# 12  Jonathan           2      1
# 13  Cristina          13      8
# 14     Pilar           3      2

# %% [markdown]
# #### Show visually the frequency distribution of the `time_grades` dataset.

# %%
time_grades.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0C9526B0>,
# ...
#       dtype=object)

# %% [markdown]
# #### Is there a correlation between `Study time` and `Grade`? Use both Pearson and Spearman correlations and comment your results.

# %%
print(time_grades['Study time'].corr(time_grades['Grade']))
print(time_grades['Study time'].corr(time_grades['Grade'], method='spearman'))
# Out:
# 0.7980456073578857
# 0.819658753036942

# %%
"""
your commments here
"""
import seaborn as sns
sns.heatmap(time_grades.corr(), annot=True)

# %% [markdown]
# #### Use matplotlib to visually plot `Study time` vs `Grade`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(time_grades['Study time'], time_grades['Grade'])
plt.show()

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlations?

# %%
"""
Spearman correlation measures relationships between variables which are not necessarily linear, Pearson does it with linear ones.
"""
