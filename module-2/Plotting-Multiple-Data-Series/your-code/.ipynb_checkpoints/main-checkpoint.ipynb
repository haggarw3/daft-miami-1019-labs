# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/aleja/daft-miami-1019-labs/module-2/Plotting-Multiple-Data-Series/data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
by_type = data.groupby('ItemType').agg({'RetailSales': 'sum', 'RetailTransfers': 'sum', 'WarehouseSales': 'sum'})
by_type
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %%
by_type.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
top_suppliers = data.groupby('Supplier').agg({'RetailSales':'sum', 'WarehouseSales': 'sum'})
top_suppliers['TotalSales'] = topten_suppliers['RetailSales'] + topten_suppliers['WarehouseSales']
topten_suppliers = top_suppliers.sort_values(['TotalSales'], ascending=False).head(10)
topten_suppliers
# Out:
#                           RetailSales  WarehouseSales  TotalSales
# Supplier
# MILLER BREWING COMPANY       35022.63       572623.41   607646.04
# CROWN IMPORTS                26707.83       579824.70   606532.53
# ANHEUSER BUSCH INC           42559.14       493856.19   536415.33
# HEINEKEN USA                 20923.17       318812.59   339735.76
# E & J GALLO WINERY           67455.63        75594.99   143050.62
# DIAGEO NORTH AMERICA INC     57656.36        54252.88   111909.24
# CONSTELLATION BRANDS         54472.51        44968.76    99441.27
# BOSTON BEER CORPORATION      10773.25        53420.91    64194.16
# YUENGLING BREWERY             9628.35        53805.32    63433.67
# FLYING DOG BREWERY LLLP      10301.08        47227.22    57528.30

# %%
topten_suppliers.plot.barh(figsize=[10.0, 5.0])

# %%
topten_suppliers.drop(['RetailSales', 'WarehouseSales'], axis=1).plot.barh(figsize=[10.0, 5.0])

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
aver_per_month = data.groupby('Month').agg({'RetailSales': 'mean', 'RetailTransfers':'mean', 'WarehouseSales':'mean'})
aver_per_month
# Out:
#        RetailSales  RetailTransfers  WarehouseSales
# Month
# 1         5.679413         5.574833       19.072137
# 2         5.939247         6.050136       20.229658
# 4         0.000000        15.707503        0.000000
# 5         7.038838         7.421817       27.310548
# 6         7.143914         6.950396       27.839069
# 8         6.409991         6.584726       28.122641
# 9         6.757254         6.419721       22.817909
# 10        6.549021         6.827827       22.289367
# 11        6.765496         7.103699       23.348862
# 12        9.078241         8.353759       21.169463

# %%
aver_per_month.plot()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
aver_per_month.plot.bar(figsize=[9.0, 5.0])

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
retails = data.groupby(['Year', 'Month', 'ItemType']).agg({'RetailSales':'sum'})
retails = retails.reset_index()
retails
# Out:
#     Year  Month      ItemType  RetailSales
# 0   2017      4          BEER         0.00
# 1   2017      4        LIQUOR         0.00
# 2   2017      4   NON-ALCOHOL         0.00
# 3   2017      4           REF         0.00
# 4   2017      4  STR_SUPPLIES         0.00
# ..   ...    ...           ...          ...
# 68  2018      2        LIQUOR     28852.31
# 69  2018      2   NON-ALCOHOL       812.84
# 70  2018      2           REF        41.52
# 71  2018      2  STR_SUPPLIES        47.76
# 72  2018      2          WINE     29409.39
#
# [73 rows x 4 columns]

# %%
DATA = data.pivot_table(index=['Year', 'Month'], columns=['ItemType'], values=['RetailSales']).reset_index()
# DATA = DATA[DATA['Year']== 2017]
DATA
# Out:
#           Year Month RetailSales                                      \
# ItemType                    BEER DUNNAGE KEGS     LIQUOR NON-ALCOHOL
# 0         2017     4    0.000000     NaN  NaN   0.000000    0.000000
# 1         2017     5   14.455945     NaN  NaN  12.136614         NaN
# 2         2017     6   15.831398     0.0  0.0  11.937073   17.031408
# 3         2017     8   13.145051     0.0  0.0  11.090986   16.287761
# 4         2017     9   14.181189     0.0  0.0  11.191029   13.848750
# 5         2017    10   12.817128     0.0  0.0  11.021571   13.509000
# 6         2017    11   12.428722     0.0  0.0  11.774866   13.769726
# 7         2017    12   16.065864     0.0  0.0  15.867440   18.033425
# 8         2018     1    9.728371     0.0  0.0   9.485519   10.313380
# 9         2018     2   10.688251     0.0  0.0   9.817050   10.289114
#
#
# ItemType       REF STR_SUPPLIES      WINE
# 0         0.000000     0.000000  0.000000
# 1              NaN          NaN  3.913331
# ...

# %%
def year_month(u, v):
    return str(u) + '/' + str(v)
DATA['Year/Month'] = list(map(year_month, DATA['Year'], DATA['Month']))
DATA
# Out:
#           Year Month RetailSales                                      \
# ItemType                    BEER DUNNAGE KEGS     LIQUOR NON-ALCOHOL
# 0         2017     4    0.000000     NaN  NaN   0.000000    0.000000
# 1         2017     5   14.455945     NaN  NaN  12.136614         NaN
# 2         2017     6   15.831398     0.0  0.0  11.937073   17.031408
# 3         2017     8   13.145051     0.0  0.0  11.090986   16.287761
# 4         2017     9   14.181189     0.0  0.0  11.191029   13.848750
# 5         2017    10   12.817128     0.0  0.0  11.021571   13.509000
# 6         2017    11   12.428722     0.0  0.0  11.774866   13.769726
# 7         2017    12   16.065864     0.0  0.0  15.867440   18.033425
# 8         2018     1    9.728371     0.0  0.0   9.485519   10.313380
# 9         2018     2   10.688251     0.0  0.0   9.817050   10.289114
#
#                                           Year/Month
# ItemType       REF STR_SUPPLIES      WINE
# ...

# %%
DATA.plot(x='Year/Month', y = ['RetailSales'], figsize=(15,10))

# %%
x['RetailSales']['BEER']
# Out:
# 0     0.000000
# 1    14.455945
# 2    15.831398
# 3    13.145051
# 4    14.181189
# 5    12.817128
# 6    12.428722
# 7    16.065864
# 8     9.728371
# 9    10.688251
# Name: BEER, dtype: float64

# %%
# retails =data.groupby(['Year', 'Month', 'ItemType']).agg({'RetailSales':'sum'})
retails.plot(x = 'Year', y = 'RetailSales' )

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
DATA[['RetailSales']].plot.bar()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
import seaborn as sns
sns.lmplot('RetailSales', 'RetailTransfers', hue='ItemType',data=data, fit_reg=False)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data['RetailTransfers'].isna().values.any()
# Out:
# False

# %%
sns.pairplot(data, hue='ItemType')

# %%
sns.pairplot(data[['RetailSales', 'RetailTransfers', 'WarehouseSales', 'ItemType']], hue='ItemType')
