# %%
import pandas as pd
import numpy as np
import seaborn as sns



zillow_2016 = pd.read_csv('/Users/katherineling/Downloads/zillow-prize-1/properties_2016.csv')

pd.set_option('display.max_columns', None)

zillow_2016
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0         10754147                    NaN                       NaN
# 1         10759547                    NaN                       NaN
# 2         10843547                    NaN                       NaN
# 3         10859147                    NaN                       NaN
# 4         10879947                    NaN                       NaN
# ...            ...                    ...                       ...
# 2985212  168176230                    NaN                       NaN
# 2985213   14273630                    NaN                       NaN
# 2985214  168040630                    NaN                       NaN
# ...

# %%
# zillow_2016['pooltypeid2'].unique()

# zillow_2016.loc[zillow_2016.pooltypeid2 == 1.]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda2/envs/py37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'threequarterbathnbr'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-4f18183dfe3a> in <module>
# ...

# %%
# zillow_2016.isna().sum()

# %%
# zillow_2016 = zillow_2016.drop(columns=['architecturalstyletypeid','buildingclasstypeid','decktypeid','finishedfloor1squarefeet', 
#                           'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6',
#                           'poolsizesum','storytypeid', 'yardbuildingsqft17','yardbuildingsqft26', 'taxdelinquencyyear'])

# %%
zillow_2016.isna().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           2173698
# basementsqft                    2983589
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingqualitytypeid           1046729
# calculatedbathnbr                128912
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# fips                              11437
# fireplacecnt                    2672580
# fullbathcnt                      128912
# garagecarcnt                    2101950
# garagetotalsqft                 2101950
# hashottuborspa                  2916203
# heatingorsystemtypeid           1178816
# latitude                          11437
# longitude                         11437
# lotsizesquarefeet                276099
# poolcnt                         2467683
# pooltypeid10                    2948278
# pooltypeid2                     2953142
# pooltypeid7                     2499758
# ...

# %%
zillow_2016['fireplaceflag'].fillna("False", inplace = True) 
zillow_2016['hashottuborspa'].fillna("False", inplace = True) 
zillow_2016['airconditioningtypeid'].fillna(5.0, inplace = True) 
zillow_2016['basementsqft'].fillna(0., inplace = True) 
zillow_2016['bathroomcnt'].fillna(0., inplace = True) 
zillow_2016['bedroomcnt'].fillna(0., inplace = True) 
zillow_2016['fireplacecnt'].fillna(0., inplace = True) 
zillow_2016['fullbathcnt'].fillna(0., inplace = True) 
zillow_2016['calculatedbathnbr'].fillna(0., inplace = True) 
zillow_2016['garagecarcnt'].fillna(0., inplace = True) 
zillow_2016['heatingorsystemtypeid'].fillna(13., inplace = True) 
zillow_2016['poolcnt'].fillna(0., inplace = True)
zillow_2016['pooltypeid10'].fillna(0., inplace = True)
zillow_2016['pooltypeid2'].fillna(0., inplace = True)
zillow_2016['pooltypeid7'].fillna(0., inplace = True)
zillow_2016['roomcnt'].fillna(0., inplace = True)
zillow_2016['threequarterbathnbr'].fillna(0., inplace = True)
zillow_2016['typeconstructiontypeid'].fillna(0., inplace = True)
zillow_2016['numberofstories'].fillna(0., inplace = True)
zillow_2016['taxdelinquencyflag'].fillna('N', inplace = True)
zillow_2016['garagetotalsqft'].fillna(0., inplace = True)

# %%
zillow_2016.loc[zillow_2016.basementsqft != 0.]
# Out:
# Empty DataFrame
# Columns: [parcelid, airconditioningtypeid, basementsqft, bathroomcnt, bedroomcnt, buildingqualitytypeid, calculatedfinishedsquarefeet, fips, fireplacecnt, garagecarcnt, garagetotalsqft, hashottuborspa, heatingorsystemtypeid, latitude, longitude, lotsizesquarefeet, poolcnt, pooltypeid10, pooltypeid7, propertycountylandusecode, propertylandusetypeid, propertyzoningdesc, rawcensustractandblock, regionidcity, regionidcounty, regionidneighborhood, regionidzip, roomcnt, threequarterbathnbr, typeconstructiontypeid, unitcnt, yearbuilt, numberofstories, fireplaceflag, structuretaxvaluedollarcnt, taxvaluedollarcnt, assessmentyear, landtaxvaluedollarcnt, taxamount, taxdelinquencyflag, censustractandblock]
# Index: []

# %%
zillow_2016 = zillow_2016.dropna(subset=['buildingqualitytypeid'])
zillow_2016 = zillow_2016.dropna(subset=['calculatedfinishedsquarefeet'])
zillow_2016 = zillow_2016.dropna(subset=['finishedsquarefeet12'])
zillow_2016 = zillow_2016.dropna(subset=['fips'])
zillow_2016 = zillow_2016.dropna(subset=['lotsizesquarefeet'])
zillow_2016 = zillow_2016.dropna(subset=['propertycountylandusecode'])
zillow_2016 = zillow_2016.dropna(subset=['propertylandusetypeid'])
zillow_2016 = zillow_2016.dropna(subset=['regionidcity'])
zillow_2016 = zillow_2016.dropna(subset=['regionidcounty'])
zillow_2016 = zillow_2016.dropna(subset=['regionidneighborhood'])
zillow_2016 = zillow_2016.dropna(subset=['regionidzip'])
zillow_2016 = zillow_2016.dropna(subset=['bathroomcnt'])
zillow_2016 = zillow_2016.dropna(subset=['taxvaluedollarcnt'])
zillow_2016 = zillow_2016.dropna(subset=['yearbuilt'])
zillow_2016 = zillow_2016.dropna(subset=['structuretaxvaluedollarcnt'])
zillow_2016 = zillow_2016.dropna(subset=['taxamount'])
zillow_2016 = zillow_2016.dropna(subset=['landtaxvaluedollarcnt'])
zillow_2016 = zillow_2016.dropna(subset=['propertyzoningdesc'])
zillow_2016 = zillow_2016.dropna(subset=['unitcnt'])
zillow_2016 = zillow_2016.dropna(subset=['censustractandblock'])

# %%
zillow_2016.isna().sum()
# Out:
# parcelid                        0
# airconditioningtypeid           0
# basementsqft                    0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedfinishedsquarefeet    0
# fips                            0
# fireplacecnt                    0
# garagecarcnt                    0
# garagetotalsqft                 0
# hashottuborspa                  0
# heatingorsystemtypeid           0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# poolcnt                         0
# pooltypeid10                    0
# pooltypeid7                     0
# propertycountylandusecode       0
# propertylandusetypeid           0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidneighborhood            0
# regionidzip                     0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

zillow_2016.corr()

# f, ax = plt.subplots(figsize=(20,20))

# heatmap = sns.heatmap(zillow_2016.corr())

# heatmap

# zillow_2016[['parcelid', 'poolcnt','pooltypeid10', 'pooltypeid2', 'pooltypeid7']].head(100)

# zillow_2016.loc[zillow_2016.pooltypeid2 == 1.]

# zillow_2016.shape
# Out:
#                               parcelid  airconditioningtypeid  basementsqft  \
# parcelid                      1.000000               0.280398           NaN
# airconditioningtypeid         0.280398               1.000000           NaN
# basementsqft                       NaN                    NaN           NaN
# bathroomcnt                  -0.154504              -0.411967           NaN
# bedroomcnt                   -0.131672              -0.118928           NaN
# buildingqualitytypeid         0.094359               0.371942           NaN
# calculatedbathnbr            -0.154504              -0.411967           NaN
# calculatedfinishedsquarefeet -0.097664              -0.268968           NaN
# finishedsquarefeet12         -0.097664              -0.268968           NaN
# fips                               NaN                    NaN           NaN
# fireplacecnt                       NaN                    NaN           NaN
# ...

# %%
zillow_2016[['parcelid', 'censustractandblock', 'rawcensustractandblock']]
# Out:
#          parcelid  censustractandblock  rawcensustractandblock
# 1245     10717217         6.037134e+13            6.037134e+07
# 1246     10718048         6.037134e+13            6.037134e+07
# 1247     10718101         6.037134e+13            6.037134e+07
# 1248     10718224         6.037134e+13            6.037134e+07
# 1249     10718347         6.037134e+13            6.037134e+07
# ...           ...                  ...                     ...
# 2973570  11062205         6.037117e+13            6.037117e+07
# 2973608  10909641         6.037144e+13            6.037144e+07
# 2973669  11770199         6.037228e+13            6.037228e+07
# 2973674  11703145         6.037235e+13            6.037235e+07
# 2973676  12205678         6.037238e+13            6.037238e+07
#
# [814292 rows x 3 columns]

# %%
zillow_2016['pooltypeid2'].unique()
# Out:
# array([0.])

# %%
zillow_2016[['parcelid', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'taxamount']]
# Out:
#          parcelid  structuretaxvaluedollarcnt  taxvaluedollarcnt  taxamount
# 1245     10717217                    118400.0           384180.0    4915.66
# 1246     10718048                    407992.0          1019980.0   11815.72
# 1247     10718101                    159612.0           233658.0    3063.96
# 1248     10718224                    270282.0           529674.0    6740.37
# 1249     10718347                    236017.0           525927.0    6663.79
# ...           ...                         ...                ...        ...
# 2973570  11062205                    235724.0           557167.0    6858.04
# 2973608  10909641                    431400.0          1006647.0   12350.85
# 2973669  11770199                     43924.0            79396.0    1074.83
# 2973674  11703145                     67251.0           270741.0    3352.35
# 2973676  12205678                     62683.0           175516.0    2285.20
#
# [814292 rows x 4 columns]

# %%
zillow_2016[['parcelid', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12']]
# Out:
#          parcelid  calculatedfinishedsquarefeet  finishedsquarefeet12
# 1245     10717217                        1766.0                1766.0
# 1246     10718048                        3085.0                3085.0
# 1247     10718101                        2401.0                2401.0
# 1248     10718224                        2397.0                2397.0
# 1249     10718347                        2574.0                2574.0
# ...           ...                           ...                   ...
# 2973570  11062205                        2112.0                2112.0
# 2973608  10909641                        3877.0                3877.0
# 2973669  11770199                         792.0                 792.0
# 2973674  11703145                        1114.0                1114.0
# 2973676  12205678                        1270.0                1270.0
#
# [814292 rows x 3 columns]

# %%
# zillow_2016 = zillow_2016.drop(columns=['calculatedbathnbr','fullbathcnt', 'finishedsquarefeet12', 'pooltypeid2'])

# %%
zillow_2016.shape
# Out:
# (814292, 41)

# %%
zillow_2016
# Out:
#          parcelid  airconditioningtypeid  basementsqft  bathroomcnt  \
# 1245     10717217                    5.0           0.0          2.0
# 1246     10718048                    1.0           0.0          3.0
# 1247     10718101                    1.0           0.0          3.0
# 1248     10718224                    1.0           0.0          3.0
# 1249     10718347                    1.0           0.0          3.0
# ...           ...                    ...           ...          ...
# 2973570  11062205                    1.0           0.0          3.0
# 2973608  10909641                    1.0           0.0          4.0
# 2973669  11770199                    5.0           0.0          1.0
# 2973674  11703145                    5.0           0.0          2.0
# 2973676  12205678                    5.0           0.0          2.0
#
#          bedroomcnt  buildingqualitytypeid  calculatedfinishedsquarefeet  \
# 1245            3.0                    4.0                        1766.0
# ...

# %%
# zillow_2016['airconditioningtypeid'].hist()
# zillow_2016['airconditioningtypeid'].unique()

# aircon13 = zillow_2016.loc[zillow_2016.airconditioningtypeid == 13.]


indexNames = zillow_2016[ zillow_2016['airconditioningtypeid'] == 13. ].index

zillow_2016.drop(indexNames, inplace=True)

# %%
zillow_2016['airconditioningtypeid'].unique()
# Out:
# array([5., 1., 9.])

# %%
zillow_2016['airconditioningtypeid'].hist()

# %%
indexNames = zillow_2016[ zillow_2016['airconditioningtypeid'] == 9. ].index

zillow_2016[ zillow_2016['airconditioningtypeid'] == 9. ]

zillow_2016.drop(indexNames, inplace=True)

# %%
zillow_2016['airconditioningtypeid'].unique()
# Out:
# array([5., 1.])

# %%
zillow_2016['airconditioningtypeid'].dtypes

zillow_2016['airconditioningtypeid'] = zillow_2016['airconditioningtypeid'].replace(5., 0)
zillow_2016['airconditioningtypeid'] = zillow_2016['airconditioningtypeid'].astype('category')

zillow_2016['airconditioningtypeid']
# Out:
# 1245       0.0
# 1246       1.0
# 1247       1.0
# 1248       1.0
# 1249       1.0
#           ...
# 2973570    1.0
# 2973608    1.0
# 2973669    0.0
# 2973674    0.0
# 2973676    0.0
# Name: airconditioningtypeid, Length: 814287, dtype: category
# Categories (2, float64): [0.0, 1.0]

# %%
zillow_2016['basementsqft'].dtypes


zillow_2016['basementsqft'].hist()

zillow_2016['basementsqft'].unique()

zillow_2016 = zillow_2016.drop(columns=['basementsqft'])

zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet    fips  \
# 1245                       4.0                        1766.0  6037.0
# ...

# %%
zillow_2016['bathroomcnt'].dtypes
zillow_2016['bathroomcnt'].unique()
# zillow_2016['bathroomcnt'].hist()

zillow_2016[ zillow_2016['bathroomcnt'] > 7.5 ]

zillow_2016.boxplot(column=['bathroomcnt'])

#remove outliers?

# %%
zillow_2016['bedroomcnt'].dtypes
zillow_2016['bedroomcnt'].unique()

# zillow_2016['bathroomcnt'].hist()

zillow_2016.boxplot(column=['bedroomcnt'])

#remove outliers?

# %%
zillow_2016['buildingqualitytypeid'].dtypes
zillow_2016['buildingqualitytypeid'].unique()

# zillow_2016['buildingqualitytypeid'].hist()

zillow_2016.boxplot(column=['buildingqualitytypeid'])

#convert to categorical? but then won't it have too many categories??

# %%
zillow_2016['calculatedfinishedsquarefeet'].dtypes

f, ax = plt.subplots(figsize=(10,10))

# zillow_2016['calculatedfinishedsquarefeet'].hist()

zillow_2016['calculatedfinishedsquarefeet'].unique()

zillow_2016.boxplot(column=['calculatedfinishedsquarefeet'])

#remove outliers?

# %%
zillow_2016['fips'].dtypes

zillow_2016['fips'].unique()

zillow_2016 = zillow_2016.drop(columns=['fips'])

zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  fireplacecnt  \
# 1245                       4.0                        1766.0           0.0
# ...

# %%
# zillow_2016['fireplacecnt'].dtypes

# zillow_2016['fireplacecnt'].unique()

# zillow_2016 = zillow_2016.drop(columns=['fireplacecnt'])

zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  garagecarcnt  \
# 1245                       4.0                        1766.0           0.0
# ...

# %%
# zillow_2016['garagecarcnt'].unique()

# zillow_2016['garagecarcnt'].dtypes

# zillow_2016['garagecarcnt'].hist()

# zillow_2016[ zillow_2016['garagecarcnt'] != 0 ]

# zillow_2016 = zillow_2016.drop(columns=['garagecarcnt', 'garagetotalsqft'])

zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet hashottuborspa  \
# 1245                       4.0                        1766.0          False
# ...

# %%
zillow_2016['hashottuborspa'].unique()

zillow_2016[ zillow_2016['hashottuborspa'] == True ]

zillow_2016['hashottuborspa'] = zillow_2016['hashottuborspa'].replace('False', False)

zillow_2016['hashottuborspa'].unique()

zillow_2016['hashottuborspa'].dtypes
# Out:
# dtype('bool')

# %%
zillow_2016['heatingorsystemtypeid'].unique()

zillow_2016['heatingorsystemtypeid'].hist()

zillow_2016['heatingorsystemtypeid'].dtype
# Out:
# dtype('float64')

# %%
zillow_2016['latitude'].dtype
zillow_2016['longitude'].dtype
# Out:
# dtype('float64')

# %%
zillow_2016['lotsizesquarefeet'].dtype

zillow_2016['lotsizesquarefeet'].hist()

#how to scale histograms??

# %%
zillow_2016['poolcnt'].dtype

zillow_2016[ zillow_2016['poolcnt'] == 0. ]

zillow_2016['poolcnt'] = zillow_2016['poolcnt'].replace('0.', 0)

zillow_2016['poolcnt'] = zillow_2016['poolcnt'].replace('1.', 1)

zillow_2016['poolcnt'].astype('category')

zillow_2016['poolcnt'].dtype

# zillow_2016['poolcnt'].unique()
# Out:
# dtype('float64')

# %%
zillow_2016['pooltypeid10'].dtype
zillow_2016['pooltypeid10'].unique()

zillow_2016[ zillow_2016['pooltypeid10'] != 0. ]
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1341     10738466                   1.0          2.0         4.0
# 1497     10781996                   0.0          2.0         4.0
# 1691     10828764                   0.0          2.0         3.0
# 1694     10829908                   1.0          3.0         2.0
# 1822     10861345                   1.0          4.0         3.0
# ...           ...                   ...          ...         ...
# 2967107  12609618                   0.0          2.0         3.0
# 2967220  12641606                   1.0          2.0         2.0
# 2967323  12669473                   0.0          4.0         4.0
# 2967329  12671363                   0.0          2.0         3.0
# 2967436  12697745                   0.0          2.0         3.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1341                       4.0                        1924.0            True
# ...

# %%
zillow_2016['pooltypeid7'].dtype
zillow_2016['pooltypeid7'].unique()

zillow_2016[ zillow_2016['pooltypeid7'] != 0. ]
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# 1250     10718693                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973434  10899755                   1.0          2.0         3.0
# 2973436  11538534                   1.0          2.0         2.0
# 2973542  10962363                   1.0          3.0         4.0
# 2973559  11952965                   1.0          5.0         5.0
# 2973608  10909641                   1.0          4.0         5.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
zillow_2016['propertycountylandusecode'].dtype
zillow_2016['propertycountylandusecode'].unique()

#reduce number of categories?
# Out:
# array(['0101', '0100', '010C', '010E', '0104', '010D', '0108', '012C',
#        '0103', '0109', '01DC', '010F', '010G', '010H', '010M', '012E',
#        '01HC', '010V', '0200', '0140', '0133', '0110', '0102', '0700',
#        '0131', '0106', '0121', '0120', '103', '020V', '070G', '0600',
#        '0400', '302C', '0130', '010X', '010', '0105', '0113', '0710',
#        '10G', '0300', '201', '100V', '10C', '0741', '2003', '300V',
#        '070M', '0123', '010Y', '0111', '1002', '101', '071P', '0134',
#        '010L', '200'], dtype=object)

# %%
zillow_2016['propertylandusetypeid'].dtype
zillow_2016['propertylandusetypeid'].unique()

#change to numerical??
# Out:
# dtype('float64')

# %%
zillow_2016['propertyzoningdesc'].dtype

zillow_2016['propertyzoningdesc'].unique()

#reduce number of categories
# Out:
# array(['LARS', 'LARE15', 'LARE11', 'LARD2', 'LAR1', 'LARD1.5', 'LARD3',
#        'LARA', 'AHRPD10000', 'AHR3*', 'AHR17000*', 'AHRPD51V-R',
#        'AHRPD51U-R', 'AHR17000-C', 'AHRPD51U*', 'AHRA10000*', 'AHR26250*',
#        'LCR110000*', 'LCC2*', 'LAR3', 'LAC2', 'LAWC', 'LAOS', 'LARE40',
#        'LARE9', 'LAR4', 'LAC1', 'LAM1', 'LAR2', 'BUR1HY', 'BUR4*',
#        'BUR1*', 'BUR1YY', 'SFR1*', 'LARZ5', 'LAA1', 'LARD4', 'LAA2',
#        'LAMR1', 'LARD6', 'SCUR2', 'SCNU5', 'SCUR3', 'SCUR1', 'SCCP',
#        'SCSP', 'SCUR4', 'LCA11*', 'SCUR5', 'INR3YY', 'INR1YY', 'HAR3YY',
#        'HAR1YY', 'HAR2*', 'TORR-LO', 'TOPR-LO', 'TORR-MH', 'TORR-MD',
#        'GARR-MD', 'CCR3*', 'LCR1YY', 'CCR1YY', 'CCR2*', 'CC-R3', 'CCR1AY',
#        'CCR2YY', 'CCR1Z*', 'SMR1*', 'SMR2*', 'SMOP2*', 'SMOP4*', 'SMR3*',
#        'CCPD*', 'LAR5', 'WDR2*', 'WDR4*', 'BHR4YY', 'BHR1*', 'LARE20',
#        'LCRA1*', 'LCR3*', 'LCR111000*', 'LCR2-1', 'LCR2YY', 'LARD5',
# ...

# %%
zillow_2016['rawcensustractandblock'].dtype

zillow_2016['rawcensustractandblock'].unique()
# Out:
# array([60371344.232003  , 60371344.24200501, 60371344.231001  , ...,
#        60377010.00303   , 60373015.023002  , 60372972.012001  ])

# %%
zillow_2016['regionidcity'].dtype

zillow_2016['regionidcity'].unique()

#convert to categorical?
# Out:
# array([ 12447.,   9840.,  37688., 396054.,  54311.,  42150.,  54722.,
#         51617.,  26964.,  48424.,  12520.,  54299.,  47019.,  45457.,
#         46298.,  33612.,  51861.,  30908.,  39308.])

# %%
zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
zillow_2016['regionidcounty'].dtype

zillow_2016['regionidcounty'].unique()

zillow_2016.drop(columns=['regionidcounty'])
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
zillow_2016['regionidcity'].dtype

zillow_2016['regionidcity'].unique()

#change to categorical?
# Out:
# array([ 12447.,   9840.,  37688., 396054.,  54311.,  42150.,  54722.,
#         51617.,  26964.,  48424.,  12520.,  54299.,  47019.,  45457.,
#         46298.,  33612.,  51861.,  30908.,  39308.])

# %%
zillow_2016['regionidcity'].dtype

zillow_2016['regionidcity'].unique()

#change to categorical?

# %%
zillow_2016['regionidneighborhood'].dtype
zillow_2016['regionidneighborhood'].unique()
# Out:
# array([268588.,  30731.,  48570., 764089., 764098., 155228., 764099.,
#        764097., 764090., 764094., 764096., 762527.,  51224., 763011.,
#         40548.,  32368.,  27987.,  51906.,  47950.,  41466.,  13176.,
#        268548.,  27080., 268002.,  41131.,  46795., 268551.,  47880.,
#         25449.,  27431., 274049., 763680., 116375., 265889.,  34213.,
#         40215.,  33952., 268249.,  27328.,  27484.,  31817., 403184.,
#        116646.,  13017.,  33183., 275078.,  37835.,  37739.,   6952.,
#         48200.,  26134., 115729., 118208., 763220., 224568., 761099.,
#        763218.,  36630., 416334., 763219., 274750.,   7877., 276514.,
#        762186., 763527.,  11950., 762183., 268097., 762193., 117183.,
#        259315., 762191., 762188., 762189., 116415., 762185.,  21056.,
#        762190., 274514., 403142., 117954., 113910., 761541., 268293.,
#        761542., 761545., 761546., 761547., 117023., 761544., 262098.,
# ...

# %%
zillow_2016['regionidzip'].dtype
zillow_2016['regionidzip'].unique()
# Out:
# array([96339., 96342., 96338., 96389., 96336., 96337., 96387., 96355.,
#        96364., 96354., 96341., 96349., 96379., 96415., 96411., 96414.,
#        96420., 96410., 96424., 96412., 96426., 96058., 96450., 96375.,
#        96451., 96446., 96452., 96447., 96449., 96086., 96436., 96437.,
#        96027., 96049., 96438., 96368., 96366., 96361., 96282., 96284.,
#        96370., 96047., 96371., 96369., 96356., 96346., 96374., 96373.,
#        96377., 96352., 96401., 96378., 96403., 96024., 96137., 96107.,
#        96162., 96105., 96026., 96129., 96095., 95997., 96097., 96128.,
#        96127., 96000., 96152., 96015., 96045., 96006., 96030., 96150.,
#        96151., 96149., 96016., 96048., 96005., 96029., 96050., 96120.,
#        96116., 96018., 96043., 95989., 95999., 95988., 95987., 96001.,
#        96017., 95986., 95991., 95992., 96039., 95996., 95995., 95993.,
#        96007., 96038., 96014., 96044., 96004., 96012., 96013., 96023.,
# ...

# %%
zillow_2016['roomcnt'].dtype
zillow_2016['roomcnt'].unique()

zillow_2016['roomcnt'].hist()

zillow_2016[ zillow_2016['roomcnt'] != 0. ]

zillow_2016 = zillow_2016.drop(columns=['roomcnt'])

# %%
zillow_2016

zillow_2016['threequarterbathnbr'].dtype
zillow_2016['threequarterbathnbr'].unique()

zillow_2016 = zillow_2016 = zillow_2016.drop(columns=['threequarterbathnbr'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda2/envs/py37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'threequarterbathnbr'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-becd72235a4d> in <module>
#       1 zillow_2016
# ...

# %%
zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
# zillow_2016['typeconstructiontypeid'].dtype
# zillow_2016['typeconstructiontypeid'].unique()

# zillow_2016 = zillow_2016 = zillow_2016.drop(columns=['typeconstructiontypeid'])

zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
zillow_2016['unitcnt'].dtype
zillow_2016['unitcnt'].unique()

# %%
zillow_2016['yearbuilt'].dtype
zillow_2016['yearbuilt'].unique()

zillow_2016['yearbuilt'] = zillow_2016['yearbuilt'].astype('int')

zillow_2016['yearbuilt'] = zillow_2016['yearbuilt'].astype('category')

zillow_2016['yearbuilt'].dtype

#make it ordered?
# Out:
# CategoricalDtype(categories=[1812, 1833, 1865, 1870, 1875, 1876, 1877, 1879, 1880, 1881,
#                   ...
#                   2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#                  ordered=False)

# %%
zillow_2016['numberofstories'].dtype
# zillow_2016['numberofstories'].unique()

zillow_2016['numberofstories'] = zillow_2016['numberofstories'].astype('int')

zillow_2016['numberofstories'] = zillow_2016['numberofstories'].astype('category')


zillow_2016['numberofstories'].dtypes

#make it ordered?
# Out:
# CategoricalDtype(categories=[0, 1, 2], ordered=False)

# %%
zillow_2016['fireplaceflag'].dtype
zillow_2016['fireplaceflag'].unique()

zillow_2016['fireplaceflag'] = zillow_2016['fireplaceflag'].replace('False', False)

zillow_2016[zillow_2016['fireplaceflag'] == True ]

zillow_2016 = zillow_2016 = zillow_2016.drop(columns=['fireplaceflag'])

# %%
zillow_2016

zillow_2016['structuretaxvaluedollarcnt'].dtype
zillow_2016['structuretaxvaluedollarcnt'].unique()
# Out:
# array([118400., 407992., 159612., ..., 479161., 715107.,  67251.])

# %%
zillow_2016
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1245     10717217                   0.0          2.0         3.0
# 1246     10718048                   1.0          3.0         5.0
# 1247     10718101                   1.0          3.0         5.0
# 1248     10718224                   1.0          3.0         4.0
# 1249     10718347                   1.0          3.0         4.0
# ...           ...                   ...          ...         ...
# 2973570  11062205                   1.0          3.0         3.0
# 2973608  10909641                   1.0          4.0         5.0
# 2973669  11770199                   0.0          1.0         3.0
# 2973674  11703145                   0.0          2.0         2.0
# 2973676  12205678                   0.0          2.0         2.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1245                       4.0                        1766.0           False
# ...

# %%
zillow_2016['assessmentyear'] = zillow_2016['assessmentyear'].astype('int')

zillow_2016['assessmentyear'] = zillow_2016['assessmentyear'].astype('category')

#make it ordered category?

# %%
zillow_2016['taxdelinquencyflag'].dtype
zillow_2016['taxdelinquencyflag'].unique()

zillow_2016[zillow_2016['taxdelinquencyflag'] == 'Y' ]
# Out:
#          parcelid airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 1275     10724202                   1.0          5.0         4.0
# 1355     10741092                   1.0          4.0         4.0
# 1362     10743595                   1.0          2.0         3.0
# 1464     10774040                   0.0          2.0         3.0
# 1551     10796806                   0.0          1.0         2.0
# ...           ...                   ...          ...         ...
# 2973094  11524045                   1.0          2.0         2.0
# 2973298  10794046                   1.0          2.0         2.0
# 2973352  11587335                   1.0          3.0         3.0
# 2973370  11781204                   0.0          2.0         2.0
# 2973608  10909641                   1.0          4.0         5.0
#
#          buildingqualitytypeid  calculatedfinishedsquarefeet  hashottuborspa  \
# 1275                       1.0                        4612.0           False
# ...

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

zillow_2017 = pd.read_csv('/Users/katherineling/Downloads/zillow-prize-1/properties_2017.csv')

zillow_2017
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0        10754147                    NaN                       NaN
# 1        10759547                    NaN                       NaN
# 2        10843547                    NaN                       NaN
# 3        10859147                    NaN                       NaN
# 4        10879947                    NaN                       NaN
# ...           ...                    ...                       ...
# 2985212  12170430                    NaN                       NaN
# 2985213  11422430                    NaN                       NaN
# 2985214  17203030                    NaN                       NaN
# ...

# %%
zillow_2017.dtypes
# Out:
# parcelid                          int64
# airconditioningtypeid           float64
# architecturalstyletypeid        float64
# basementsqft                    float64
# bathroomcnt                     float64
# bedroomcnt                      float64
# buildingclasstypeid             float64
# buildingqualitytypeid           float64
# calculatedbathnbr               float64
# decktypeid                      float64
# finishedfloor1squarefeet        float64
# calculatedfinishedsquarefeet    float64
# finishedsquarefeet12            float64
# finishedsquarefeet13            float64
# finishedsquarefeet15            float64
# finishedsquarefeet50            float64
# finishedsquarefeet6             float64
# fips                            float64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# garagetotalsqft                 float64
# hashottuborspa                   object
# ...
