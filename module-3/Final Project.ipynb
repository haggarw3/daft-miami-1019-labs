# %%
import pandas as pd
import numpy as np



zillow = pd.read_csv('/Users/katherineling/Downloads/zillow-prize-1/properties_2016.csv')

pd.set_option('display.max_columns', None)

zillow 


# zillow.head()

# zillow_prices = pd.read_csv('/Users/katherineling/Downloads/zillow-prize-1/train_2016_v2.csv')

# zillow_prices

# zillow['regionidzip']

# zillow.shape
# Out:
#           parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0         10754147                    NaN                       NaN
# 1         10759547                    NaN                       NaN
# 2         10843547                    NaN                       NaN
# 3         10859147                    NaN                       NaN
# 4         10879947                    NaN                       NaN
# ...            ...                    ...                       ...
# 2985212  168176230                    NaN                       NaN
# 2985213   14273630                    NaN                       NaN
# 2985214  168040630                    NaN                       NaN
# 2985215  168040830                    NaN                       NaN
# 2985216  168040430                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0                 NaN          0.0         0.0                  NaN
# ...
